# %%
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from matplotlib import pyplot as plt
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
from xgboost import XGBRegressor

# %%
def get_data():
    #get train data
    train_data_path ='train.csv'
    train = pd.read_csv(train_data_path)

    #get test data
    test_data_path ='test.csv'
    test = pd.read_csv(test_data_path)

    return train , test

def get_combined_data():
    #reading train data
    train , test = get_data()

    target = train.SalePrice
    train.drop(['SalePrice'],axis = 1 , inplace = True)

    combined = train.append(test)
    combined.reset_index(inplace=True)
    combined.drop(['index', 'Id'], inplace=True, axis=1)
    return combined, target

#Load train and test data into pandas DataFrames
train_data, test_data = get_data()

#Combine train and test data to process them together
combined, target = get_combined_data()

# %%
combined.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  2919.000000  2433.000000    2919.000000  2919.000000  2919.000000
# mean     57.137718    69.305795   10168.114080     6.089072     5.564577
# std      42.517628    23.344905    7886.996359     1.409947     1.113131
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7478.000000     5.000000     5.000000
# 50%      50.000000    68.000000    9453.000000     6.000000     5.000000
# 75%      70.000000    80.000000   11570.000000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  2919.000000   2919.000000  2896.000000  2918.000000  2918.000000  ...
# mean   1971.312778   1984.264474   102.201312   441.423235    49.582248  ...
# std      30.291442     20.894344   179.334253   455.610826   169.205611  ...
# min    1872.000000   1950.000000     0.000000     0.000000     0.000000  ...
# 25%    1953.500000   1965.000000     0.000000     0.000000     0.000000  ...
# 50%    1973.000000   1993.000000     0.000000   368.500000     0.000000  ...
# 75%    2001.000000   2004.000000   164.000000   733.000000     0.000000  ...
# max    2010.000000   2010.000000  1600.000000  5644.000000  1526.000000  ...
#
#         GarageArea   WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  \
# count  2918.000000  2919.000000  2919.000000    2919.000000  2919.000000
# mean    472.874572    93.709832    47.486811      23.098321     2.602261
# std     215.394815   126.526589    67.575493      64.244246    25.188169
# min       0.000000     0.000000     0.000000       0.000000     0.000000
# 25%     320.000000     0.000000     0.000000       0.000000     0.000000
# 50%     480.000000     0.000000    26.000000       0.000000     0.000000
# 75%     576.000000   168.000000    70.000000       0.000000     0.000000
# max    1488.000000  1424.000000   742.000000    1012.000000   508.000000
#
#        ScreenPorch     PoolArea       MiscVal       MoSold       YrSold
# count  2919.000000  2919.000000   2919.000000  2919.000000  2919.000000
# mean     16.062350     2.251799     50.825968     6.213087  2007.792737
# std      56.184365    35.663946    567.402211     2.714762     1.314964
# min       0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%       0.000000     0.000000      0.000000     4.000000  2007.000000
# 50%       0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%       0.000000     0.000000      0.000000     8.000000  2009.000000
# max     576.000000   800.000000  17000.000000    12.000000  2010.000000
#
# [8 rows x 36 columns]

# %%
def get_cols_with_no_nans(df,col_type):
    '''
    Arguments :
    df : The dataframe to process
    col_type : 
          num : to only get numerical columns with no nans
          no_num : to only get nun-numerical columns with no nans
          all : to get any columns with no nans    
    '''
    if (col_type == 'num'):
        predictors = df.select_dtypes(exclude=['object'])
    elif (col_type == 'no_num'):
        predictors = df.select_dtypes(include=['object'])
    elif (col_type == 'all'):
        predictors = df
    else :
        print('Error : choose a type (num, no_num, all)')
        return 0
    cols_with_no_nans = []
    for col in predictors.columns:
        if not df[col].isnull().any():
            cols_with_no_nans.append(col)
    return cols_with_no_nans

# %%
num_cols = get_cols_with_no_nans(combined , 'num')
cat_cols = get_cols_with_no_nans(combined , 'no_num')

# %%
print ('Number of numerical columns with no nan values :',len(num_cols))
print ('Number of nun-numerical columns with no nan values :',len(cat_cols))
# Out:
# Number of numerical columns with no nan values : 25
# Number of nun-numerical columns with no nan values : 20

# %%
combined = combined[num_cols + cat_cols]
combined.hist(figsize = (12,10))
plt.show()

# %%
train_data = train_data[num_cols + cat_cols]
train_data['Target'] = target

C_mat = train_data.corr()
fig = plt.figure(figsize = (15,15))

sb.heatmap(C_mat, vmax = .8, square = True)
plt.show()

# %%
def oneHotEncode(df,colNames):
    for col in colNames:
        if( df[col].dtype == np.dtype('object')):
            dummies = pd.get_dummies(df[col],prefix=col)
            df = pd.concat([df,dummies],axis=1)

            #drop the encoded column
            df.drop([col],axis = 1 , inplace=True)
    return df
    

print('There were {} columns before encoding categorical features'.format(combined.shape[1]))
combined = oneHotEncode(combined, cat_cols)
print('There are {} columns after encoding categorical features'.format(combined.shape[1]))
# Out:
# There were 45 columns before encoding categorical features
# There are 149 columns after encoding categorical features

# %%
def split_combined():
    global combined
    train = combined[:1460]
    test = combined[1460:]

    return train , test 
  
train, test = split_combined()

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               19200
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 184,065
# Trainable params: 184,065
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
NN_model.fit(train, target, epochs=20, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# Epoch 1/20
# 37/37 [==============================] - 0s 3ms/step - loss: 26485.0078 - mean_absolute_error: 26485.0078 - val_loss: 32411.0312 - val_mean_absolute_error: 32411.0312
#
# Epoch 00001: val_loss did not improve from 30975.18164
# Epoch 2/20
# 37/37 [==============================] - 0s 3ms/step - loss: 27249.9902 - mean_absolute_error: 27249.9902 - val_loss: 32974.2930 - val_mean_absolute_error: 32974.2930
#
# Epoch 00002: val_loss did not improve from 30975.18164
# Epoch 3/20
# 37/37 [==============================] - 0s 3ms/step - loss: 27182.7422 - mean_absolute_error: 27182.7422 - val_loss: 31318.5176 - val_mean_absolute_error: 31318.5176
#
# Epoch 00003: val_loss did not improve from 30975.18164
# Epoch 4/20
# 37/37 [==============================] - 0s 3ms/step - loss: 27068.3750 - mean_absolute_error: 27068.3750 - val_loss: 33947.2930 - val_mean_absolute_error: 33947.2930
#
# Epoch 00004: val_loss did not improve from 30975.18164
# Epoch 5/20
# 37/37 [==============================] - 0s 3ms/step - loss: 27350.1230 - mean_absolute_error: 27350.1230 - val_loss: 30300.8906 - val_mean_absolute_error: 30300.8906
#
# Epoch 00005: val_loss improved from 30975.18164 to 30300.89062, saving model to Weights-005--30300.89062.hdf5
# Epoch 6/20
# 37/37 [==============================] - 0s 3ms/step - loss: 29038.5215 - mean_absolute_error: 29038.5215 - val_loss: 29001.9590 - val_mean_absolute_error: 29001.9590
#
# Epoch 00006: val_loss improved from 30300.89062 to 29001.95898, saving model to Weights-006--29001.95898.hdf5
# Epoch 7/20
# 37/37 [==============================] - 0s 4ms/step - loss: 26662.0645 - mean_absolute_error: 26662.0645 - val_loss: 32852.9883 - val_mean_absolute_error: 32852.9883
#
# Epoch 00007: val_loss did not improve from 29001.95898
# Epoch 8/20
# 37/37 [==============================] - 0s 4ms/step - loss: 25982.5352 - mean_absolute_error: 25982.5352 - val_loss: 31131.4277 - val_mean_absolute_error: 31131.4277
#
# Epoch 00008: val_loss did not improve from 29001.95898
# Epoch 9/20
# 37/37 [==============================] - 0s 4ms/step - loss: 26822.3105 - mean_absolute_error: 26822.3105 - val_loss: 28404.1875 - val_mean_absolute_error: 28404.1875
#
# Epoch 00009: val_loss improved from 29001.95898 to 28404.18750, saving model to Weights-009--28404.18750.hdf5
# Epoch 10/20
# 37/37 [==============================] - 0s 3ms/step - loss: 25456.2441 - mean_absolute_error: 25456.2441 - val_loss: 31220.8262 - val_mean_absolute_error: 31220.8262
#
# Epoch 00010: val_loss did not improve from 28404.18750
# Epoch 11/20
# 37/37 [==============================] - 0s 3ms/step - loss: 26176.8652 - mean_absolute_error: 26176.8652 - val_loss: 29172.5312 - val_mean_absolute_error: 29172.5312
#
# Epoch 00011: val_loss did not improve from 28404.18750
# Epoch 12/20
# 37/37 [==============================] - 0s 3ms/step - loss: 24843.7520 - mean_absolute_error: 24843.7520 - val_loss: 29771.8555 - val_mean_absolute_error: 29771.8555
#
# Epoch 00012: val_loss did not improve from 28404.18750
# Epoch 13/20
# 37/37 [==============================] - 0s 4ms/step - loss: 24882.5840 - mean_absolute_error: 24882.5840 - val_loss: 33227.2969 - val_mean_absolute_error: 33227.2969
#
# Epoch 00013: val_loss did not improve from 28404.18750
# Epoch 14/20
# 37/37 [==============================] - ETA: 0s - loss: 28687.5254 - mean_absolute_error: 28687.525 - 0s 4ms/step - loss: 27658.7422 - mean_absolute_error: 27658.7422 - val_loss: 28074.5332 - val_mean_absolute_error: 28074.5332
#
# Epoch 00014: val_loss improved from 28404.18750 to 28074.53320, saving model to Weights-014--28074.53320.hdf5
# Epoch 15/20
# 37/37 [==============================] - 0s 3ms/step - loss: 25248.0625 - mean_absolute_error: 25248.0625 - val_loss: 29502.9180 - val_mean_absolute_error: 29502.9180
#
# Epoch 00015: val_loss did not improve from 28074.53320
# Epoch 16/20
# 37/37 [==============================] - 0s 4ms/step - loss: 24740.0781 - mean_absolute_error: 24740.0781 - val_loss: 28561.5938 - val_mean_absolute_error: 28561.5938
#
# Epoch 00016: val_loss did not improve from 28074.53320
# Epoch 17/20
# 37/37 [==============================] - 0s 3ms/step - loss: 24480.5449 - mean_absolute_error: 24480.5449 - val_loss: 28348.5156 - val_mean_absolute_error: 28348.5156
#
# Epoch 00017: val_loss did not improve from 28074.53320
# Epoch 18/20
# 37/37 [==============================] - 0s 4ms/step - loss: 25560.8262 - mean_absolute_error: 25560.8262 - val_loss: 34002.3789 - val_mean_absolute_error: 34002.3789
#
# Epoch 00018: val_loss did not improve from 28074.53320
# Epoch 19/20
# 37/37 [==============================] - 0s 3ms/step - loss: 25291.4238 - mean_absolute_error: 25291.4238 - val_loss: 28762.8359 - val_mean_absolute_error: 28762.8359
#
# Epoch 00019: val_loss did not improve from 28074.53320
# Epoch 20/20
# 37/37 [==============================] - 0s 3ms/step - loss: 23421.2441 - mean_absolute_error: 23421.2441 - val_loss: 27778.4297 - val_mean_absolute_error: 27778.4297
#
# Epoch 00020: val_loss improved from 28074.53320 to 27778.42969, saving model to Weights-020--27778.42969.hdf5

# %%
wights_file = 'Weights-020--27778.42969.hdf5' # choose the best checkpoint 
NN_model.load_weights(wights_file) # load it
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
def make_submission(prediction, sub_name):
    my_submission = pd.DataFrame({'Id':pd.read_csv('test.csv').Id,'SalePrice':prediction})
    my_submission.to_csv('{}.csv'.format(sub_name),index=False)
    print('A submission file has been made')

predictions = NN_model.predict(test)
make_submission(predictions[:,0],'submission(NN).csv')
# Out:
# A submission file has been made

# %%
predictions
# Out:
# array([[111521.41],
#        [119675.36],
#        [177961.22],
#        ...,
#        [143673.72],
#        [116915.43],
#        [211886.08]], dtype=float32)

# %%
test
